# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth on your own computer, follow the installation instructions on our Github page [here](https://docs.unsloth.ai/get-started/installing-+-updating).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save)

# %% [markdown]
# ### News

# %% [markdown]
# **Read our [blog post](https://unsloth.ai/blog/r1-reasoning) for guidance on how to train reasoning models.**
#
# Visit our docs for all our [model uploads](https://docs.unsloth.ai/get-started/all-our-models) and [notebooks](https://docs.unsloth.ai/get-started/unsloth-notebooks).

# %% [markdown]
# ### Installation

# %%
# %%capture
# Skip restarting message in Colab
import sys; modules = list(sys.modules.keys())
for x in modules: sys.modules.pop(x) if "PIL" in x or "google" in x else None

# !pip install unsloth vllm
# !pip install --upgrade pillow

# %% [markdown]
# ### Unsloth

# %% [markdown]
# Load up `Qwen 2.5 3B Instruct`, and set parameters

# %%
from unsloth import FastLanguageModel, is_bfloat16_supported
import torch
max_seq_length = 1024 # Can increase for longer reasoning traces
lora_rank = 64 # Larger rank = smarter, but slower

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "Qwen/Qwen2.5-3B-Instruct",
    max_seq_length = max_seq_length,
    load_in_4bit = True, # False for LoRA 16bit
    fast_inference = True, # Enable vLLM fast inference
    max_lora_rank = lora_rank,
    gpu_memory_utilization = 0.5, # Reduce if out of memory
)

model = FastLanguageModel.get_peft_model(
    model,
    r = lora_rank, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = [
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj",
    ], # Remove QKVO if out of memory
    lora_alpha = lora_rank,
    use_gradient_checkpointing = "unsloth", # Enable long context finetuning
    random_state = 3407,
)
# Out:
# Unsloth: Patching Xformers to fix some performance issues.
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# INFO 03-12 06:59:18 __init__.py:207] Automatically detected platform cuda.
# ==((====))==  Unsloth 2025.3.9: Fast Qwen2 patching. Transformers: 4.48.3. vLLM: 0.7.3.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: vLLM loading unsloth/qwen2.5-3b-instruct-unsloth-bnb-4bit with actual GPU utilization = 49.53%
# Unsloth: Your GPU has CUDA compute capability 7.5 with VRAM = 14.74 GB.
# Unsloth: Using conservativeness = 1.0. Chunked prefill tokens = 1024. Num Sequences = 192.
# Unsloth: vLLM's KV Cache can use up to 4.88 GB. Also swap space = 2 GB.
# WARNING 03-12 06:59:22 config.py:2448] Casting torch.bfloat16 to torch.float16.
# INFO 03-12 06:59:35 config.py:549] This model supports multiple tasks: {'reward', 'score', 'generate', 'classify', 'embed'}. Defaulting to 'generate'.
# Unsloth: vLLM Bitsandbytes config using kwargs = {'load_in_8bit': False, 'load_in_4bit': True, 'bnb_4bit_compute_dtype': 'float16', 'bnb_4bit_quant_storage': 'uint8', 'bnb_4bit_quant_type': 'nf4', 'bnb_4bit_use_double_quant': True, 'llm_int8_enable_fp32_cpu_offload': False, 'llm_int8_has_fp16_weight': False, 'llm_int8_skip_modules': ['lm_head', 'multi_modal_projector', 'merger', 'modality_projection', 'model.layers.2.mlp', 'model.layers.3.mlp', 'model.layers.30.mlp'], 'llm_int8_threshold': 6.0}
# INFO 03-12 06:59:35 llm_engine.py:234] Initializing a V0 LLM engine (v0.7.3) with config: model='unsloth/qwen2.5-3b-instruct-unsloth-bnb-4bit', speculative_config=None, tokenizer='unsloth/qwen2.5-3b-instruct-unsloth-bnb-4bit', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=1024, download_dir=None, load_format=LoadFormat.BITSANDBYTES, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=bitsandbytes, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda:0, decoding_config=DecodingConfig(guided_decoding_backend='xgrammar'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=unsloth/qwen2.5-3b-instruct-unsloth-bnb-4bit, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=False, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"level":0,"splitting_ops":[],"compile_sizes":[],"cudagraph_capture_sizes":[192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":192}, use_cached_outputs=False,
# tokenizer_config.json:   0%|          | 0.00/7.36k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/271 [00:00<?, ?B/s]
# INFO 03-12 06:59:38 cuda.py:178] Cannot use FlashAttention-2 backend for Volta and Turing GPUs.
# INFO 03-12 06:59:38 cuda.py:226] Using XFormers backend.
# INFO 03-12 06:59:39 model_runner.py:1110] Starting to load model unsloth/qwen2.5-3b-instruct-unsloth-bnb-4bit...
# INFO 03-12 06:59:39 loader.py:1089] Loading weights with BitsAndBytes quantization.  May take a while ...
# INFO 03-12 06:59:40 weight_utils.py:254] Using model weights format ['*.safetensors']
# model.safetensors:   0%|          | 0.00/2.36G [00:00<?, ?B/s]
# INFO 03-12 06:59:56 weight_utils.py:270] Time spent downloading weights for unsloth/qwen2.5-3b-instruct-unsloth-bnb-4bit: 16.344863 seconds
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# INFO 03-12 07:00:03 model_runner.py:1115] Loading model weights took 2.2160 GB
# INFO 03-12 07:00:03 punica_selector.py:18] Using PunicaWrapperGPU.
# INFO 03-12 07:00:14 worker.py:267] Memory profiling takes 9.60 seconds
# INFO 03-12 07:00:14 worker.py:267] the current vLLM instance can use total_gpu_memory (14.74GiB) x gpu_memory_utilization (0.50) = 7.30GiB
# INFO 03-12 07:00:14 worker.py:267] model weights take 2.22GiB; non_torch_memory takes 0.03GiB; PyTorch activation peak memory takes 1.05GiB; the rest of the memory reserved for KV Cache is 4.01GiB.
# INFO 03-12 07:00:15 executor_base.py:111] # cuda blocks: 7300, # CPU blocks: 3640
# INFO 03-12 07:00:15 executor_base.py:116] Maximum concurrency for 1024 tokens per request: 114.06x
# INFO 03-12 07:00:17 model_runner.py:1434] Capturing cudagraphs for decoding. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI. If out-of-memory error occurs during cudagraph capture, consider decreasing `gpu_memory_utilization` or switching to eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# Capturing CUDA graph shapes: 100%|██████████| 27/27 [00:42<00:00,  1.56s/it]
# INFO 03-12 07:00:59 model_runner.py:1562] Graph capturing finished in 42 secs, took 0.62 GiB
# INFO 03-12 07:00:59 llm_engine.py:436] init engine (profile, create kv cache, warmup model) took 55.18 seconds
# tokenizer_config.json:   0%|          | 0.00/7.36k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# Unsloth 2025.3.9 patched 36 layers with 36 QKV layers, 36 O layers and 36 MLP layers.

# %% [markdown]
# ### Data Prep
# <a name="Data"></a>
#
# We directly leverage [@willccbb](https://gist.github.com/willccbb/4676755236bb08cab5f4e54a0475d6fb) for data prep and all reward functions. You are free to create your own!

# %%
import re
from datasets import load_dataset, Dataset

# Load and prep dataset
SYSTEM_PROMPT = """
Respond in the following format:
<reasoning>
...
</reasoning>
<answer>
...
</answer>
"""

XML_COT_FORMAT = """\
<reasoning>
{reasoning}
</reasoning>
<answer>
{answer}
</answer>
"""

def extract_xml_answer(text: str) -> str:
    answer = text.split("<answer>")[-1]
    answer = answer.split("</answer>")[0]
    return answer.strip()

def get_pokerbench_questions(split="train") -> Dataset:
    # Load PokerBench dataset
    data = load_dataset('RZ412/PokerBench', split=split)  # Verify actual dataset name

    # Format dataset for poker decisions
    data = data.map(lambda x: {
        'prompt': [
            {'role': 'system', 'content': SYSTEM_PROMPT},
            {'role': 'user', 'content': x['instruction']}
        ],
        'answer': x['output'].strip()  # Directly use output field
    })
    return data

dataset = get_pokerbench_questions()

# Reward functions (remain similar but might need poker-specific adjustments)
def correctness_reward_func(prompts, completions, answer, **kwargs) -> list[float]:
    responses = [completion[0]['content'] for completion in completions]
    q = prompts[0][-1]['content']
    extracted_responses = [extract_xml_answer(r) for r in responses]
    print('-'*20, f"Question:\n{q}", f"\nAnswer:\n{answer[0]}", f"\nResponse:\n{responses[0]}", f"\nExtracted:\n{extracted_responses[0]}")
    return [2.0 if r == a else 0.0 for r, a in zip(extracted_responses, answer)]

# - Poker actions have formats like "bet X", "raise Y", "fold"
# - Might want to create poker-specific format validation

def poker_action_validator(completions, **kwargs) -> list[float]:
    """Validate poker action format (e.g., 'bet 18', 'check', 'fold')"""
    pattern = r"^(bet|raise|check|call|fold)( \d+)?$"
    responses = [extract_xml_answer(completion[0]["content"]) for completion in completions]
    matches = [re.fullmatch(pattern, r.lower()) for r in responses]
    return [1.0 if match else 0.0 for match in matches]

# Other reward functions remain similar:
def strict_format_reward_func(completions, **kwargs) -> list[float]:
    """Reward function that checks if the completion has a specific format."""
    pattern = r"^<reasoning>\n.*?\n</reasoning>\n<answer>\n.*?\n</answer>\n$"
    responses = [completion[0]["content"] for completion in completions]
    matches = [re.match(pattern, r) for r in responses]
    return [0.5 if match else 0.0 for match in matches]

def soft_format_reward_func(completions, **kwargs) -> list[float]:
    """Reward function that checks if the completion has a specific format."""
    pattern = r"<reasoning>.*?</reasoning>\s*<answer>.*?</answer>"
    responses = [completion[0]["content"] for completion in completions]
    matches = [re.match(pattern, r) for r in responses]
    return [0.5 if match else 0.0 for match in matches]

def count_xml(text) -> float:
    count = 0.0
    if text.count("<reasoning>\n") == 1:
        count += 0.125
    if text.count("\n</reasoning>\n") == 1:
        count += 0.125
    if text.count("\n<answer>\n") == 1:
        count += 0.125
        count -= len(text.split("\n</answer>\n")[-1])*0.001
    if text.count("\n</answer>") == 1:
        count += 0.125
        count -= (len(text.split("\n</answer>")[-1]) - 1)*0.001
    return count

def xmlcount_reward_func(completions, **kwargs) -> list[float]:
    contents = [completion[0]["content"] for completion in completions]
    return [count_xml(c) for c in contents]

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
#
# Now set up GRPO Trainer and all configurations!

# %%
from trl import GRPOConfig, GRPOTrainer
training_args = GRPOConfig(
    use_vllm = True, # use vLLM for fast inference!
    learning_rate = 5e-6,
    adam_beta1 = 0.9,
    adam_beta2 = 0.99,
    weight_decay = 0.1,
    warmup_ratio = 0.1,
    lr_scheduler_type = "cosine",
    optim = "adamw_8bit",
    logging_steps = 1,
    bf16 = is_bfloat16_supported(),
    fp16 = not is_bfloat16_supported(),
    per_device_train_batch_size = 1,
    gradient_accumulation_steps = 1, # Increase to 4 for smoother training
    num_generations = 8, # Decrease if out of memory
    max_prompt_length = 256,
    max_completion_length = 200,
    # num_train_epochs = 1, # Set to 1 for a full training run
    max_steps = 250,
    save_steps = 250,
    max_grad_norm = 0.1,
    report_to = "none", # Can use Weights & Biases
    output_dir = "outputs",
)
# Out:
# Unsloth: We now expect `per_device_train_batch_size` to be a multiple of `num_generations`.
# We will change the batch size of 1 to the `num_generations` of 8

# %% [markdown]
# And let's run the trainer! If you scroll up, you'll see a table of rewards. The goal is to see the `reward` column increase!
#
# You might have to wait 150 to 200 steps for any action. You'll probably get 0 reward for the first 100 steps. Please be patient!
#
# | Step | Training Loss | reward    | reward_std | completion_length | kl       |
# |------|---------------|-----------|------------|-------------------|----------|
# | 1    | 0.000000      | 0.125000  | 0.000000   | 200.000000        | 0.000000 |
# | 2    | 0.000000      | 0.072375  | 0.248112   | 200.000000        | 0.000000 |
# | 3    | 0.000000      | -0.079000 | 0.163776   | 182.500000        | 0.000005 |

# %%
trainer = GRPOTrainer(
    model = model,
    processing_class = tokenizer,
    reward_funcs = [
        xmlcount_reward_func,
        soft_format_reward_func,
        strict_format_reward_func,
        #int_reward_func,
        correctness_reward_func,
        poker_action_validator,
    ],
    args = training_args,
    train_dataset = dataset,
)
trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 563,200 | Num Epochs = 1 | Total steps = 250
# O^O/ \_/ \    Batch size per device = 8 | Gradient accumulation steps = 1
# \        /    Data Parallel GPUs = 1 | Total batch size (8 x 1 x 1) = 8
#  "-____-"     Trainable parameters = 119,734,272/1,919,856,640 (6.24% trained)
# -------------------- Question:
#
#
# You are a specialist in playing 6-handed No Limit Texas Holdem. The following will be a game scenario and you need to make the optimal decision.
#
# Here is a game summary:
#
# The small blind is 0.5 chips and the big blind is 1 chips. Everyone started with 100 chips.
# The player positions involved in this game are UTG, HJ, CO, BTN, SB, BB.
# In this hand, your position is BTN, and your holding is [King of Club and Six of Club].
# Before the flop, BTN raise 2.5 chips, and BB call. Assume that all other players that is not mentioned folded.
# The flop comes Six Of Spade, Eight Of Diamond, and Seven Of Club, then BB bet 2 chips, BTN raise 8 chips, and BB call.
# The turn comes Jack Of Spade, then BB check.
#
#
# Now it is your turn to make a move.
# To remind you, the current pot size is 21.0 chips, and your holding is [King of Club and Six of Club].
#
# Decide on an action based on the strength of your hand on this board, your position, and actions before you. Do not explain your answer.
# Your optimal action is:
# Answer:
# check
# Response:
# <reasoning>
# Given your position as BTN (Third Bottom), you have the option to bet or check. Considering that you just raised and your opponent has raised even more, it suggests they think your board shows a strong hand, likely a set or better.
#
# The pot is now 136 chips. Since you think you might be ahead but you're also concerned about the strength of BB's hand, checking would preserve your chips and allow an even more aggressive move if necessary. However, betting might make your hand stronger and force a decision from BB.
#
# Given the fact that you're facing a significant raise and backraise, it's likely a strong indicator that BB has a strong hand or thinks they have a stronger hand, so betting might be too risky to show down now. Checking would play into your hand, leading to a potential showdown, but it would also be passing up an opportunity to show down your hand.
#
# Considering the scenario, checking appears to create a more optimal and balanced expected
# Extracted:
# <reasoning>
# Given your position as BTN (Third Bottom), you have the option to bet or check. Considering that you just raised and your opponent has raised even more, it suggests they think your board shows a strong hand, likely a set or better.
#
# The pot is now 136 chips. Since you think you might be ahead but you're also concerned about the strength of BB's hand, checking would preserve your chips and allow an even more aggressive move if necessary. However, betting might make your hand stronger and force a decision from BB.
#
# Given the fact that you're facing a significant raise and backraise, it's likely a strong indicator that BB has a strong hand or thinks they have a stronger hand, so betting might be too risky to show down now. Checking would play into your hand, leading to a potential showdown, but it would also be passing up an opportunity to show down your hand.
#
# Considering the scenario, checking appears to create a more optimal and balanced expected
#     <div>
#
#       <progress value='156' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/250 1:03:30 < 38:46, 0.04 it/s, Epoch 0.00/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completion_length</th>
#       <th>kl</th>
#       <th>rewards / xmlcount_reward_func</th>
#       <th>rewards / soft_format_reward_func</th>
#       <th>rewards / strict_format_reward_func</th>
#       <th>rewards / correctness_reward_func</th>
#       <th>rewards / poker_action_validator</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000100</td>
#       <td>0.068625</td>
#       <td>0.159453</td>
#       <td>199.500000</td>
#       <td>0.002899</td>
#       <td>0.068625</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000100</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>0.001293</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000100</td>
#       <td>0.137625</td>
#       <td>0.235551</td>
#       <td>197.875000</td>
#       <td>0.001280</td>
#       <td>0.012625</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>0.000899</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000200</td>
#       <td>0.225500</td>
#       <td>0.284257</td>
#       <td>192.750000</td>
#       <td>0.004957</td>
#       <td>0.100500</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000200</td>
#       <td>0.045750</td>
#       <td>0.224153</td>
#       <td>200.000000</td>
#       <td>0.004154</td>
#       <td>0.045750</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000100</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>0.001977</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000500</td>
#       <td>0.189625</td>
#       <td>0.278510</td>
#       <td>188.375000</td>
#       <td>0.012412</td>
#       <td>0.064625</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>0.000817</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000200</td>
#       <td>0.223000</td>
#       <td>0.277186</td>
#       <td>196.250000</td>
#       <td>0.005455</td>
#       <td>0.098000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.000100</td>
#       <td>0.157625</td>
#       <td>0.281569</td>
#       <td>194.125000</td>
#       <td>0.001547</td>
#       <td>0.032625</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.000000</td>
#       <td>0.221000</td>
#       <td>0.271529</td>
#       <td>194.500000</td>
#       <td>0.000754</td>
#       <td>0.096000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.000100</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>0.001422</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.000300</td>
#       <td>0.003750</td>
#       <td>0.227877</td>
#       <td>198.625000</td>
#       <td>0.006568</td>
#       <td>0.003750</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.000500</td>
#       <td>0.230625</td>
#       <td>0.298753</td>
#       <td>191.250000</td>
#       <td>0.012717</td>
#       <td>0.105625</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.000100</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>0.001273</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.000100</td>
#       <td>-0.025625</td>
#       <td>0.279026</td>
#       <td>200.000000</td>
#       <td>0.002186</td>
#       <td>-0.025625</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.000000</td>
#       <td>0.140625</td>
#       <td>0.044194</td>
#       <td>200.000000</td>
#       <td>0.000862</td>
#       <td>0.140625</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.000900</td>
#       <td>0.202375</td>
#       <td>0.378645</td>
#       <td>196.250000</td>
#       <td>0.021785</td>
#       <td>-0.047625</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.250000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.000400</td>
#       <td>0.066375</td>
#       <td>0.220702</td>
#       <td>200.000000</td>
#       <td>0.011004</td>
#       <td>0.066375</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.000300</td>
#       <td>0.081000</td>
#       <td>0.124451</td>
#       <td>198.125000</td>
#       <td>0.007154</td>
#       <td>0.081000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.000100</td>
#       <td>0.106250</td>
#       <td>0.330028</td>
#       <td>198.500000</td>
#       <td>0.002843</td>
#       <td>-0.018750</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.000200</td>
#       <td>0.462125</td>
#       <td>0.953533</td>
#       <td>199.250000</td>
#       <td>0.005986</td>
#       <td>0.087125</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.250000</td>
#       <td>0.125000</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.000100</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>0.002225</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.000100</td>
#       <td>0.176625</td>
#       <td>0.411909</td>
#       <td>189.125000</td>
#       <td>0.003071</td>
#       <td>-0.073375</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.250000</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.000200</td>
#       <td>0.140625</td>
#       <td>0.044194</td>
#       <td>200.000000</td>
#       <td>0.003936</td>
#       <td>0.140625</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.000300</td>
# Streaming output truncated to the last 5000 lines.
# Here is a game summary:
#
# The small blind is 0.5 chips and the big blind is 1 chips. Everyone started with 100 chips.
# The player positions involved in this game are UTG, HJ, CO, BTN, SB, BB.
# In this hand, your position is BB, and your holding is [Ace of Diamond and Ace of Club].
# Before the flop, UTG raise 2.0, CO call, BTN call, SB call, BB raise 15.0, UTG raise 34.0, CO all in, BTN fold, and SB fold. Assume that all other players that is not mentioned folded.
#
# Now it is your turn to make a move.
# To remind you, the current pot size is 153.0 chips, and your holding is [Ace of Diamond and Ace of Club].
#
# Decide on an action based on the strength of your hand on this board, your position, and actions before you. Do not explain your answer.
# Your optimal action is:
# Answer:
# call
# Response:
# <reasoning>
# Given the scenario, your opponent's actions indicate significant strength. Your holding is a pair of Aces, which is a strong starting hand. With the flop/call, you have a good chance to win. The pot is quite deep (153 chips), meaning your opponent likely had a strong hand as well. You should consider a re-raise to show strength and prevent further action from opponents. However, the size of the raise from the previous player (15.0 chips) suggests your opponent was not willing to call much more.
#
# Given all these factors, a decent re-raise of 20-30 chips might be prudent to maintain the strength of your hand and see what the remaining players (HJ) have to offer. It's a good balance between reiterating your strength and not overextending when the pot is so deep.
# ...
# </reasoning>
# <answer>
# Re-raise 20-30 chips
# </answer
# Extracted:
# Re-raise 20-30 chips
# </answer
# -------------------- Question:
#
#
# You are a specialist in playing 6-handed No Limit Texas Holdem. The following will be a game scenario and you need to make the optimal decision.
#
# Here is a game summary:
#
# The small blind is 0.5 chips and the big blind is 1 chips. Everyone started with 100 chips.
# The player positions involved in this game are UTG, HJ, CO, BTN, SB, BB.
# In this hand, your position is BTN, and your holding is [Ace of Diamond and Jack of Diamond].
# Before the flop, HJ raise 2.0, CO call, BTN raise 9.5, SB call, HJ call, and CO all in. Assume that all other players that is not mentioned folded.
#
# Now it is your turn to make a move.
# To remind you, the current pot size is 129.5 chips, and your holding is [Ace of Diamond and Jack of Diamond].
#
# Decide on an action based on the strength of your hand on this board, your position, and actions before you. Do not explain your answer.
# Your optimal action is:
# Answer:
# call
# Response:
# <reasoning>
# Based on the action history and pot size, it's clear that the pot is dominated by at least one pair (CO went all-in). With only a pair to compete against the set of AK, you have a very tough hole card. On the BTN position, you'd typically consider checking to get a read on the two players who have raised previously, especially since CO went all-in. However, given the strength of CO's pre-flop raise and the amount CO and HJ bet in the pot, it seems that attempting to improve your hand is unlikely to succeed given their deep stack sizes. Your best course of action is to call the pot to stay in the hand and give yourself the opportunity to observe the action and potentially get value on future streets.
#
# Since CO went all-in and value betting to win the pot is improbable, calling the pot is the most conservative and strategic option. Checking would simply allow the SB to make a decision on whether to fold, which he likely
# Extracted:
# <reasoning>
# Based on the action history and pot size, it's clear that the pot is dominated by at least one pair (CO went all-in). With only a pair to compete against the set of AK, you have a very tough hole card. On the BTN position, you'd typically consider checking to get a read on the two players who have raised previously, especially since CO went all-in. However, given the strength of CO's pre-flop raise and the amount CO and HJ bet in the pot, it seems that attempting to improve your hand is unlikely to succeed given their deep stack sizes. Your best course of action is to call the pot to stay in the hand and give yourself the opportunity to observe the action and potentially get value on future streets.
#
# Since CO went all-in and value betting to win the pot is improbable, calling the pot is the most conservative and strategic option. Checking would simply allow the SB to make a decision on whether to fold, which he likely
# -------------------- Question:
#
#
# You are a specialist in playing 6-handed No Limit Texas Holdem. The following will be a game scenario and you need to make the optimal decision.
#
# Here is a game summary:
#
# The small blind is 0.5 chips and the big blind is 1 chips. Everyone started with 100 chips.
# The player positions involved in this game are UTG, HJ, CO, BTN, SB, BB.
# In this hand, your position is CO, and your holding is [Nine of Spade and Nine of Heart].
# Before the flop, CO raise 2.3 chips, and BTN call. Assume that all other players that is not mentioned folded.
# The flop comes Jack Of Spade, Eight Of Diamond, and Three Of Club, then CO check, and BTN check.
# The turn comes Nine Of Diamond, then CO check, and BTN check.
# The river comes Two Of Heart, then CO check, and BTN bet 5 chips.
#
#
# Now it is your turn to make a move.
# To remind you, the current pot size is 11.0 chips, and your holding is [Nine of Spade and Nine of Heart].
#
# Decide on an action based on the strength of your hand on this board, your position, and actions before you. Do not explain your answer.
# Your optimal action is:
# Answer:
# raise 16
# Response:
# <reasoning>
# Given the board and current pot size, the hand [Nine of Spade and Nine of Heart] has good potential due to its high pair with a flush draw and backdoor straight draw. However, the pot is currently smaller compared to other potential raises. Considering the late position (CO), it may be beneficial to stick to your hand and attempt the river, as you have likely faced a candidates wide range of bet sizes due to the multi-way pot.
#
# The actions so far show a continuation bet from BTN, which suggests they have a decent hand. A potential continuation bet on your part could still be favorable. The fact that the pot isn't large enough to commission a super-sized river bet also supports checking instead of raising.
#
# Taking all these factors into account, checking is the most prudent action to see the river.
# ...
# </reasoning>
#
# <answer>
# Check
# </answer>
# Extracted:
# Check
# -------------------- Question:
#
#
# You are a specialist in playing 6-handed No Limit Texas Holdem. The following will be a game scenario and you need to make the optimal decision.
#
# Here is a game summary:
#
# The small blind is 0.5 chips and the big blind is 1 chips. Everyone started with 100 chips.
# The player positions involved in this game are UTG, HJ, CO, BTN, SB, BB.
# In this hand, your position is HJ, and your holding is [King of Diamond and Five of Diamond].
# Before the flop, HJ raise 2.0 chips, and BTN call. Assume that all other players that is not mentioned folded.
# The flop comes Nine Of Spade, Seven Of Spade, and Four Of Club, then HJ check, and BTN check.
# The turn comes Six Of Spade, then HJ bet 6 chips, and BTN call.
# The river comes Three Of Club, then HJ check, and BTN bet 13 chips.
#
#
# Now it is your turn to make a move.
# To remind you, the current pot size is 30.0 chips, and your holding is [King of Diamond and Five of Diamond].
#
# Decide on an action based on the strength of your hand on this board, your position, and actions before you. Do not explain your answer.
# Your optimal action is:
# Answer:
# call
# Response:
# <reasoning>
# Given the situation, HJ has bet on the turn for value or to protect their position. Facing 13 chips on the river and a pot size of 30 chips, HJ has control of the decision. Since HJ is in position and you are on the button, you can consider making your own play. Your two pair (K♦5♦) is decent but not strong against a bet like 13 chips. Preferrably, you would want to see the river if you’re in position, as it gives you odds to improve.
#
# If you see that HJ is riding your strength in hand, you might be called or maybe need to pay off. However, given the size of HJ's river bet, it seems that they might be hiding a strong hand, such a backdoor flush draw or a straight continuation bet. You might want to consider bluffing or calling if HJ bets, because they might be going for a set
# Extracted:
# <reasoning>
# Given the situation, HJ has bet on the turn for value or to protect their position. Facing 13 chips on the river and a pot size of 30 chips, HJ has control of the decision. Since HJ is in position and you are on the button, you can consider making your own play. Your two pair (K♦5♦) is decent but not strong against a bet like 13 chips. Preferrably, you would want to see the river if you’re in position, as it gives you odds to improve.
#
# If you see that HJ is riding your strength in hand, you might be called or maybe need to pay off. However, given the size of HJ's river bet, it seems that they might be hiding a strong hand, such a backdoor flush draw or a straight continuation bet. You might want to consider bluffing or calling if HJ bets, because they might be going for a set
# -------------------- Question:
#
#
# You are a specialist in playing 6-handed No Limit Texas Holdem. The following will be a game scenario and you need to make the optimal decision.
#
# Here is a game summary:
#
# The small blind is 0.5 chips and the big blind is 1 chips. Everyone started with 100 chips.
# The player positions involved in this game are UTG, HJ, CO, BTN, SB, BB.
# In this hand, your position is BB, and your holding is [King of Club and Queen of Spade].
# Before the flop, HJ raise 2.0 chips, and BB call. Assume that all other players that is not mentioned folded.
# The flop comes Nine Of Spade, Seven Of Spade, and Four Of Club, then BB check, and HJ check.
# The turn comes Six Of Spade, then BB bet 5 chips, and HJ call.
# The river comes King Of Spade, then BB check, and HJ bet 11 chips.
#
#
# Now it is your turn to make a move.
# To remind you, the current pot size is 25.0 chips, and your holding is [King of Club and Queen of Spade].
#
# Decide on an action based on the strength of your hand on this board, your position, and actions before you. Do not explain your answer.
# Your optimal action is:
# Answer:
# call
# Response:
# <reasoning>
# Given the flop of Nine of Spade, Seven of Spade, Four of Club, this is a very good starting hand against a spade strongboard (2-spade connected board). The turn card was a Six of Spade, which is not a blocker but slightly weakens the set possibility. The river card is a King of Spade, which makes the set (7-11) with the remaining card, Sew or Six Spade. HJ's decision to bet 11 chips on the turn and call a bet on the river implies that he likely had a strong hand that beat the board or contributed to it. Given that HJ can have a strong hand like set or at least a very strong drawing hand, the pot is now extremely big and the implied equity HJ has in the hand is significant.
#
# With your hand [King of Club, Queen of Spade], it's critical to not give away too much information with a weak action.
# Extracted:
# <reasoning>
# Given the flop of Nine of Spade, Seven of Spade, Four of Club, this is a very good starting hand against a spade strongboard (2-spade connected board). The turn card was a Six of Spade, which is not a blocker but slightly weakens the set possibility. The river card is a King of Spade, which makes the set (7-11) with the remaining card, Sew or Six Spade. HJ's decision to bet 11 chips on the turn and call a bet on the river implies that he likely had a strong hand that beat the board or contributed to it. Given that HJ can have a strong hand like set or at least a very strong drawing hand, the pot is now extremely big and the implied equity HJ has in the hand is significant.
#
# With your hand [King of Club, Queen of Spade], it's critical to not give away too much information with a weak action.
# -------------------- Question:
#
#
# You are a specialist in playing 6-handed No Limit Texas Holdem. The following will be a game scenario and you need to make the optimal decision.
#
# Here is a game summary:
#
# The small blind is 0.5 chips and the big blind is 1 chips. Everyone started with 100 chips.
# The player positions involved in this game are UTG, HJ, CO, BTN, SB, BB.
# In this hand, your position is BB, and your holding is [Nine of Spade and Nine of Club].
# Before the flop, HJ raise 2.0, BTN call, SB call, BB raise 14.5, HJ raise 28.0, BTN call, and SB call. Assume that all other players that is not mentioned folded.
#
# Now it is your turn to make a move.
# To remind you, the current pot size is 98.5 chips, and your holding is [Nine of Spade and Nine of Club].
#
# Decide on an action based on the strength of your hand on this board, your position, and actions before you. Do not explain your answer.
# Your optimal action is:
# Answer:
# fold
# Response:
# <reasoning>
# Given the pre-flop action, we can infer that a significant proportion of the blinds (SB and BB) and the HJ raised, indicating they likely saw value in the action. This suggests the board could be a drawing hand, but not such a strong one that the other players would raise beyond the raiser's range.
#
# The action after the two raises, where BTN called and SB followed, is particularly telling. It shows that a majority of the remaining players have a wide range, which is often a sign that a weaker drawing hand can't outdraw much.
#
# Given these factors, it seems like the board is allowing for a relatively weak bet, perhaps a check or a small bet, to capitalize on the fact that most remaining players have a wide range. The board also might include a few potential draw cards that could be misleading.
#
# Considering all these factors, the optimal action in this scenario is to make a small bet.
# </reasoning>
# <answer>
# Bet Small
# Extracted:
# Bet Small
# -------------------- Question:
#
#
# You are a specialist in playing 6-handed No Limit Texas Holdem. The following will be a game scenario and you need to make the optimal decision.
#
# Here is a game summary:
#
# The small blind is 0.5 chips and the big blind is 1 chips. Everyone started with 100 chips.
# The player positions involved in this game are UTG, HJ, CO, BTN, SB, BB.
# In this hand, your position is BTN, and your holding is [Three of Spade and Three of Diamond].
# Before the flop, BTN raise 2.5 chips, and BB call. Assume that all other players that is not mentioned folded.
# The flop comes Six Of Spade, Eight Of Diamond, and Seven Of Club, then BB check, BTN bet 2 chips, BB raise 8 chips, and BTN call.
# The turn comes Nine Of Spade, then BB check, BTN bet 26 chips, and BB raise 89 chips.
#
#
# Now it is your turn to make a move.
# To remind you, the current pot size is 136.0 chips, and your holding is [Three of Spade and Three of Diamond].
#
# Decide on an action based on the strength of your hand on this board, your position, and actions before you. Do not explain your answer.
# Your optimal action is:
# Answer:
# fold
# Response:
# <reasoning>
# From the board - Six of Spades, Eight of Diamonds, Seven of Clubs (6♠8♦7♣) - your hand (3♠3♦) is outstanding, especially considering it can make a straight (6, 7, 8, 9).
# The pot size is now at 136 chips, and your opponent (BB) has been checking all the way to this point, which is a strong indication that BB probably has a strong hand or is protecting a strong hand. BB's first bet with a raise to 8 chips could indicate a semi-bluff or a slightly weaker overhand, but the 89 chip raise to this point is a clear indication of strength.
# Given your position as BTN and the fact that BB didn't overcall your 2 chip bet, it suggests that you may have a better hand and BB has a strong hand, or BB might feel pressure to protect a strong hand. Since you have the potential
# Extracted:
# <reasoning>
# From the board - Six of Spades, Eight of Diamonds, Seven of Clubs (6♠8♦7♣) - your hand (3♠3♦) is outstanding, especially considering it can make a straight (6, 7, 8, 9).
# The pot size is now at 136 chips, and your opponent (BB) has been checking all the way to this point, which is a strong indication that BB probably has a strong hand or is protecting a strong hand. BB's first bet with a raise to 8 chips could indicate a semi-bluff or a slightly weaker overhand, but the 89 chip raise to this point is a clear indication of strength.
# Given your position as BTN and the fact that BB didn't overcall your 2 chip bet, it suggests that you may have a better hand and BB has a strong hand, or BB might feel pressure to protect a strong hand. Since you have the potential
# -------------------- Question:
#
#
# You are a specialist in playing 6-handed No Limit Texas Holdem. The following will be a game scenario and you need to make the optimal decision.
#
# Here is a game summary:
#
# The small blind is 0.5 chips and the big blind is 1 chips. Everyone started with 100 chips.
# The player positions involved in this game are UTG, HJ, CO, BTN, SB, BB.
# In this hand, your position is SB, and your holding is [Ace of Club and Three of Heart].
# Before the flop, SB raise 3.0 chips, and BB call. Assume that all other players that is not mentioned folded.
# The flop comes Ace Of Diamond, Eight Of Diamond, and Three Of Diamond, then SB check, BB bet 2 chips, and SB call.
# The turn comes Nine Of Diamond, then SB check, and BB check.
# The river comes Ten Of Diamond, then SB check, and BB bet 8 chips.
#
#
# Now it is your turn to make a move.
# To remind you, the current pot size is 18.0 chips, and your holding is [Ace of Club and Three of Heart].
#
# Decide on an action based on the strength of your hand on this board, your position, and actions before you. Do not explain your answer.
# Your optimal action is:
# Answer:
# fold
# Response:
# <reasoning>
# To make an optimal decision, we need to analyze the key aspects: the strength of your hand, your position, and the actions already taken.
#
# 1. **Hand Strength:** You have the Ace of Clubs (better than any other pair in this board) plus a Three of Hearts, which can form a strong A3 straight. Your hand is solid and has the potential to win against a few strong hands.
#
# 2. **Position:** You are the SB (second to the button), which means you are slightly behind the BTN (button), but ahead of all other seated players.
#
# 3. **Actions Before:** The SB raised, and the BB called. This popular move suggests that the BB might have a good hand. The BB then bet the turn and river, showing some aggression, but the fact that the SB is still in could mean the BB might be bluffing.
#
# 4. **Pot Size:** The pot currently contains 18 chips, and if it were much
# Extracted:
# <reasoning>
# To make an optimal decision, we need to analyze the key aspects: the strength of your hand, your position, and the actions already taken.
#
# 1. **Hand Strength:** You have the Ace of Clubs (better than any other pair in this board) plus a Three of Hearts, which can form a strong A3 straight. Your hand is solid and has the potential to win against a few strong hands.
#
# 2. **Position:** You are the SB (second to the button), which means you are slightly behind the BTN (button), but ahead of all other seated players.
#
# 3. **Actions Before:** The SB raised, and the BB called. This popular move suggests that the BB might have a good hand. The BB then bet the turn and river, showing some aggression, but the fact that the SB is still in could mean the BB might be bluffing.
#
# 4. **Pot Size:** The pot currently contains 18 chips, and if it were much
# -------------------- Question:
#
#
# You are a specialist in playing 6-handed No Limit Texas Holdem. The following will be a game scenario and you need to make the optimal decision.
#
# Here is a game summary:
#
# The small blind is 0.5 chips and the big blind is 1 chips. Everyone started with 100 chips.
# The player positions involved in this game are UTG, HJ, CO, BTN, SB, BB.
# In this hand, your position is BTN, and your holding is [King of Heart and Jack of Spade].
# Before the flop, BTN raise 2.5 chips, and BB call. Assume that all other players that is not mentioned folded.
# The flop comes Jack Of Heart, Four Of Heart, and Five Of Spade, then BB check.
#
#
# Now it is your turn to make a move.
# To remind you, the current pot size is 5.0 chips, and your holding is [King of Heart and Jack of Spade].
#
# Decide on an action based on the strength of your hand on this board, your position, and actions before you. Do not explain your answer.
# Your optimal action is:
# Answer:
# check
# Response:
# <reasoning>
# Given the board -- Jack of Heart, Four of Heart, and Five of Spade -- your holding is [King of Heart and Jack of Spade] (which is a Jack-high straight, or a possible Queen-high straight), and you are in position (Button) with the BB (Big Blind) checking. The prior raiser (BTN) raised 2.5 chips, and the caller (BB) called 1 chip to call a full raise.
#
# With the flop now showing, the board is set up for either the top two players (the raiser and the caller) to have a strong hand, or the overall strength to be closer to a middle pair situation. Since the BB is just checking, it’s likely that the raise was either a reentry bet or an overbet into a marginal scenario.
#
# You might have thoughts of a possible value bet in position just to take down the BB and maintain your chip stack. On the other hand, if
# Extracted:
# <reasoning>
# Given the board -- Jack of Heart, Four of Heart, and Five of Spade -- your holding is [King of Heart and Jack of Spade] (which is a Jack-high straight, or a possible Queen-high straight), and you are in position (Button) with the BB (Big Blind) checking. The prior raiser (BTN) raised 2.5 chips, and the caller (BB) called 1 chip to call a full raise.
#
# With the flop now showing, the board is set up for either the top two players (the raiser and the caller) to have a strong hand, or the overall strength to be closer to a middle pair situation. Since the BB is just checking, it’s likely that the raise was either a reentry bet or an overbet into a marginal scenario.
#
# You might have thoughts of a possible value bet in position just to take down the BB and maintain your chip stack. On the other hand, if
# -------------------- Question:
#
#
# You are a specialist in playing 6-handed No Limit Texas Holdem. The following will be a game scenario and you need to make the optimal decision.
#
# Here is a game summary:
#
# The small blind is 0.5 chips and the big blind is 1 chips. Everyone started with 100 chips.
# The player positions involved in this game are UTG, HJ, CO, BTN, SB, BB.
# In this hand, your position is BB, and your holding is [Ace of Club and Seven of Spade].
# Before the flop, SB raise 3.0 chips, and BB call. Assume that all other players that is not mentioned folded.
# The flop comes Five Of Club, Five Of Diamond, and Ace Of Heart, then SB check, and BB check.
# The turn comes Five Of Spade, then SB check, BB bet 8 chips, and SB call.
# The river comes Eight Of Club, then SB check.
#
#
# Now it is your turn to make a move.
# To remind you, the current pot size is 22.0 chips, and your holding is [Ace of Club and Seven of Spade].
#
# Decide on an action based on the strength of your hand on this board, your position, and actions before you. Do not explain your answer.
# Your optimal action is:
# Answer:
# bet 17
# Response:
# <reasoning>
# Given the initial bet from the small blind (SB) and the fact that BB (the current player) raised to 3.0 chips, we can assume that BB had a hand that was at least semi-strong, making it less likely that SB was bluffing. On the flop, the board turned [5c 5d A♠], which is a relatively tough board for many weak hands, though not necessarily unbeatable for some high-value hands like AA and QQ.
#
# After the turn with [5s], the pot should be more difficult to win as it changes from a pocket pair (or a lower-higher X) to a pair, especially for any pocket X with an overcard (like A7 and 77) or any kind of connected low cards (like JJ, AQ, or 77).
#
# The current pot size is 22 chips. BB bet 8 chips on the turn, which suggests that BB feels confident about the
# Extracted:
# <reasoning>
# Given the initial bet from the small blind (SB) and the fact that BB (the current player) raised to 3.0 chips, we can assume that BB had a hand that was at least semi-strong, making it less likely that SB was bluffing. On the flop, the board turned [5c 5d A♠], which is a relatively tough board for many weak hands, though not necessarily unbeatable for some high-value hands like AA and QQ.
#
# After the turn with [5s], the pot should be more difficult to win as it changes from a pocket pair (or a lower-higher X) to a pair, especially for any pocket X with an overcard (like A7 and 77) or any kind of connected low cards (like JJ, AQ, or 77).
#
# The current pot size is 22 chips. BB bet 8 chips on the turn, which suggests that BB feels confident about the
# -------------------- Question:
#
#
# You are a specialist in playing 6-handed No Limit Texas Holdem. The following will be a game scenario and you need to make the optimal decision.
#
# Here is a game summary:
#
# The small blind is 0.5 chips and the big blind is 1 chips. Everyone started with 100 chips.
# The player positions involved in this game are UTG, HJ, CO, BTN, SB, BB.
# In this hand, your position is CO, and your holding is [Jack of Diamond and Nine of Diamond].
# Before the flop, CO raise 2.3 chips, and BTN call. Assume that all other players that is not mentioned folded.
# The flop comes Ace Of Diamond, Eight Of Diamond, and Three Of Diamond, then CO check, and BTN check.
# The turn comes King Of Heart, then CO check, and BTN bet 8 chips.
#
#
# Now it is your turn to make a move.
# To remind you, the current pot size is 14.0 chips, and your holding is [Jack of Diamond and Nine of Diamond].
#
# Decide on an action based on the strength of your hand on this board, your position, and actions before you. Do not explain your answer.
# Your optimal action is:
# Answer:
# call
# Response:
# <reasoning>
# Given your position (CO) and the previous actions, you have a slight advantage in this pot. The bet made on the turn by BTN (8 chips) is a strong bet that suggests BTN may be in a good position, but it's also possible that BTN was on a drawing hand like a flush draw or a set.
#
# You hold [Jack of Diamond and Nine of Diamond], which is a potentially strong pair, but just a backdoor flush draw. However, since BTN made a bet, it is likely that BTN has at least a set or has at least a strong draw. With the board [Ace of Diamond, Eight of Diamond, Three of Diamond, King of Heart], a second draw to a flush is unlikely without a drawing hand.
#
# Given this, your optimal action would be to fold, since BTN might have a better hand or a strong drawing hand that would win the pot.
# ...
# </reasoning>
# <answer>
# fold
# </answer>
# Extracted:
# fold
# -------------------- Question:
#
#
# You are a specialist in playing 6-handed No Limit Texas Holdem. The following will be a game scenario and you need to make the optimal decision.
#
# Here is a game summary:
#
# The small blind is 0.5 chips and the big blind is 1 chips. Everyone started with 100 chips.
# The player positions involved in this game are UTG, HJ, CO, BTN, SB, BB.
# In this hand, your position is UTG, and your holding is [Five of Heart and Five of Club].
# Before the flop, UTG raise 2.0, BTN raise 7.5, and SB all in. Assume that all other players that is not mentioned folded.
#
# Now it is your turn to make a move.
# To remind you, the current pot size is 110.5 chips, and your holding is [Five of Heart and Five of Club].
#
# Decide on an action based on the strength of your hand on this board, your position, and actions before you. Do not explain your answer.
# Your optimal action is:
# Answer:
# fold
# Response:
# <reasoning>
# Given the pre-flop action:
# - UTG raises with [Five of Heart, Five of Club] (which is a strong starting hand).
# - BTN raises with even stronger support, likely[positioning and possibly an even better hand).
# - SB just called the raise, possibly thinking they have a powerful hand that lets them push all-in.
#
# To break even and keep going, a call is often the right action. However, since BTN raised significantly, it might make sense to bet or raise, as BTN might be looking for a speculative raise or a continuation bet. So, I will raise instead of just calling, trying to steal or push the BTN back.
#
# The current pot size is 110.5 chips, and it’s not clear if BTN’s raise is purely value or speculative. If BTN’s raise was value (to a pair, full house, or a strong draw), folding would likely result in a small win. If it was speculative, with 3
# Extracted:
# <reasoning>
# Given the pre-flop action:
# - UTG raises with [Five of Heart, Five of Club] (which is a strong starting hand).
# - BTN raises with even stronger support, likely[positioning and possibly an even better hand).
# - SB just called the raise, possibly thinking they have a powerful hand that lets them push all-in.
#
# To break even and keep going, a call is often the right action. However, since BTN raised significantly, it might make sense to bet or raise, as BTN might be looking for a speculative raise or a continuation bet. So, I will raise instead of just calling, trying to steal or push the BTN back.
#
# The current pot size is 110.5 chips, and it’s not clear if BTN’s raise is purely value or speculative. If BTN’s raise was value (to a pair, full house, or a strong draw), folding would likely result in a small win. If it was speculative, with 3
# -------------------- Question:
#
#
# You are a specialist in playing 6-handed No Limit Texas Holdem. The following will be a game scenario and you need to make the optimal decision.
#
# Here is a game summary:
#
# The small blind is 0.5 chips and the big blind is 1 chips. Everyone started with 100 chips.
# The player positions involved in this game are UTG, HJ, CO, BTN, SB, BB.
# In this hand, your position is CO, and your holding is [Four of Heart and Four of Diamond].
# Before the flop, CO raise 2.3 chips, and BB call. Assume that all other players that is not mentioned folded.
# The flop comes Ten Of Heart, Three Of Spade, and Two Of Diamond, then BB bet 4 chips, and CO call.
# The turn comes Five Of Diamond, then BB check, CO bet 16 chips, and BB raise 46 chips.
#
#
# Now it is your turn to make a move.
# To remind you, the current pot size is 75.0 chips, and your holding is [Four of Heart and Four of Diamond].
#
# Decide on an action based on the strength of your hand on this board, your position, and actions before you. Do not explain your answer.
# Your optimal action is:
# Answer:
# call
# Response:
# <reasoning>
# Given the situation, BB currently has to decide whether to call CO's bet of 16 chips with a potential board of 10H-3S-2D-TD-D5 and to also consider CO's action after the turn card was the Five of Diamond.
#
# The board is developing into a somewhat suited holding but not overly supreme with a pair (44), so CO's bet of 16 chips might be trying to convey information about his hand or it could be a raise to try to get out of a tricky spot.
#
# As CO bet so aggressively after checking on the turn and followed by BB raise, it could indicate a strong hand like a made straight or straight flush (e.g., 55T9T), ace-high (55 or KK), or a set.
#
# Given your position as CO, you could either:
# - Re-raise to strengthen your position or put additional pressure on BB, or
# - Call and go
# Extracted:
# <reasoning>
# Given the situation, BB currently has to decide whether to call CO's bet of 16 chips with a potential board of 10H-3S-2D-TD-D5 and to also consider CO's action after the turn card was the Five of Diamond.
#
# The board is developing into a somewhat suited holding but not overly supreme with a pair (44), so CO's bet of 16 chips might be trying to convey information about his hand or it could be a raise to try to get out of a tricky spot.
#
# As CO bet so aggressively after checking on the turn and followed by BB raise, it could indicate a strong hand like a made straight or straight flush (e.g., 55T9T), ace-high (55 or KK), or a set.
#
# Given your position as CO, you could either:
# - Re-raise to strengthen your position or put additional pressure on BB, or
# - Call and go
# -------------------- Question:
#
#
# You are a specialist in playing 6-handed No Limit Texas Holdem. The following will be a game scenario and you need to make the optimal decision.
#
# Here is a game summary:
#
# The small blind is 0.5 chips and the big blind is 1 chips. Everyone started with 100 chips.
# The player positions involved in this game are UTG, HJ, CO, BTN, SB, BB.
# In this hand, your position is HJ, and your holding is [King of Spade and Jack of Spade].
# Before the flop, HJ raise 2.0 chips, and BB call. Assume that all other players that is not mentioned folded.
# The flop comes Eight Of Heart, Eight Of Club, and Ten Of Club, then BB check, HJ bet 1 chips, BB raise 5 chips, and HJ call.
# The turn comes King Of Club, then BB check, HJ bet 11 chips, and BB call.
# The river comes Two Of Heart, then BB check.
#
#
# Now it is your turn to make a move.
# To remind you, the current pot size is 31.0 chips, and your holding is [King of Spade and Jack of Spade].
#
# Decide on an action based on the strength of your hand on this board, your position, and actions before you. Do not explain your answer.
# Your optimal action is:
# Answer:
# check
# Response:
# <reasoning>
# Given your position (HJ), and the actions of the previous players, your hand (King of Spade and Jack of Spade) can be considered a strong starting hand. The flop, turn, and river all contain two clubs (K-C and T-C) but no other pairs or strong suited connecting cards. This makes it somewhat difficult to compete with the strength of the current hole cards.
#
# The fact that BB raised and then called when HJ bet aggressively into a smaller bet implies that BB likely had a hand that could compete with yours or even make you feel like you need to re-evaluate your position.
#
# Since HJ bet 11 chips on the turn after BB called 5 chips, it suggests HJ believes BB had some quality. Given this, it might be more prudent to check as HJ is setting up the pot and BB is likely to look for value. If HJ checks and you believe you have the best hand, you could consider
# Extracted:
# <reasoning>
# Given your position (HJ), and the actions of the previous players, your hand (King of Spade and Jack of Spade) can be considered a strong starting hand. The flop, turn, and river all contain two clubs (K-C and T-C) but no other pairs or strong suited connecting cards. This makes it somewhat difficult to compete with the strength of the current hole cards.
#
# The fact that BB raised and then called when HJ bet aggressively into a smaller bet implies that BB likely had a hand that could compete with yours or even make you feel like you need to re-evaluate your position.
#
# Since HJ bet 11 chips on the turn after BB called 5 chips, it suggests HJ believes BB had some quality. Given this, it might be more prudent to check as HJ is setting up the pot and BB is likely to look for value. If HJ checks and you believe you have the best hand, you could consider
# -------------------- Question:
#
#
# You are a specialist in playing 6-handed No Limit Texas Holdem. The following will be a game scenario and you need to make the optimal decision.
#
# Here is a game summary:
#
# The small blind is 0.5 chips and the big blind is 1 chips. Everyone started with 100 chips.
# The player positions involved in this game are UTG, HJ, CO, BTN, SB, BB.
# In this hand, your position is SB, and your holding is [King of Club and Queen of Diamond].
# Before the flop, UTG raise 2.0 chips, SB raise 10.0 chips, and UTG call. Assume that all other players that is not mentioned folded.
# The flop comes Ten Of Diamond, Six Of Heart, and Four Of Heart, then SB check, UTG bet 11 chips, and SB call.
# The turn comes Eight Of Diamond, then SB check, and UTG bet 47 chips.
#
#
# Now it is your turn to make a move.
# To remind you, the current pot size is 90.0 chips, and your holding is [King of Club and Queen of Diamond].
#
# Decide on an action based on the strength of your hand on this board, your position, and actions before you. Do not explain your answer.
# Your optimal action is:
# Answer:
# fold
# Response:
# <reasoning>
# Given the board [Ten of Diamond, Six of Heart, Four of Heart, Eight of Diamond], it shows a somewhat tight board, but not dominated. Your opponent has bet 11 chips into a 90 chip pot on the flop, which is a decent-sized bet, suggesting they may have a decent hand or they are value betting. UTG also made a bet on the turn, increasing the bet size to 47 chips, which is a large one, probably indicating a strong hand.
#
# ...
# -------------------- Question:
#
#
# You are a specialist in playing 6-handed No Limit Texas Holdem. The following will be a game scenario and you need to make the optimal decision.
#
# Here is a game summary:
#
# The small blind is 0.5 chips and the big blind is 1 chips. Everyone started with 100 chips.
# The player positions involved in this game are UTG, HJ, CO, BTN, SB, BB.
# In this hand, your position is CO, and your holding is [King of Heart and Queen of Heart].
# Before the flop, HJ raise 2.0 chips, CO raise 6.5 chips, and HJ call. Assume that all other players that is not mentioned folded.
# The flop comes Jack Of Spade, King Of Spade, and Five Of Diamond, then HJ bet 3 chips.
#
#
# Now it is your turn to make a move.
# To remind you, the current pot size is 17.0 chips, and your holding is [King of Heart and Queen of Heart].
#
# Decide on an action based on the strength of your hand on this board, your position, and actions before you. Do not explain your answer.
# Your optimal action is:
# Answer:
# raise 10
# Response:
# <reasoning>
# Given your position as CO, you have a strong hand (KQ) that is suited. The villain (HJ) has raised and then bet after the flop, suggesting he may have a strong hand or a draw. There is only one raise (6.5 chips) before your position, so the strength of the action shows the community cards aren't particularly strong enough to deter a raise from HJ. The pot size is 17 chips, which suggests the board might have been attractive enough for two raises. With two raises, it's unlikely that a small call or check would make sense.
#
# Considering your hand (KQ) and the fact that you are behind in this pot, you might want to bet aggressively to see if HJ is raising with a strong hand or a strong draw. If he's holding a strong hand and wishes to see a turn or river, he might go all-in with a strong hand.
#
# Thus, you should consider betting
# Extracted:
# <reasoning>
# Given your position as CO, you have a strong hand (KQ) that is suited. The villain (HJ) has raised and then bet after the flop, suggesting he may have a strong hand or a draw. There is only one raise (6.5 chips) before your position, so the strength of the action shows the community cards aren't particularly strong enough to deter a raise from HJ. The pot size is 17 chips, which suggests the board might have been attractive enough for two raises. With two raises, it's unlikely that a small call or check would make sense.
#
# Considering your hand (KQ) and the fact that you are behind in this pot, you might want to bet aggressively to see if HJ is raising with a strong hand or a strong draw. If he's holding a strong hand and wishes to see a turn or river, he might go all-in with a strong hand.
#
# Thus, you should consider betting
# -------------------- Question:
#
#
# You are a specialist in playing 6-handed No Limit Texas Holdem. The following will be a game scenario and you need to make the optimal decision.
#
# Here is a game summary:
#
# The small blind is 0.5 chips and the big blind is 1 chips. Everyone started with 100 chips.
# The player positions involved in this game are UTG, HJ, CO, BTN, SB, BB.
# In this hand, your position is BTN, and your holding is [Ace of Spade and Five of Spade].
# Before the flop, UTG raise 2.0, HJ raise 6.5, BTN raise 14.0, BB raise 26.0, UTG fold, and HJ fold. Assume that all other players that is not mentioned folded.
#
# Now it is your turn to make a move.
# To remind you, the current pot size is 49.0 chips, and your holding is [Ace of Spade and Five of Spade].
#
# Decide on an action based on the strength of your hand on this board, your position, and actions before you. Do not explain your answer.
# Your optimal action is:
# Answer:
# call
# Response:
# <reasoning>
# Given your holding of A♠5♠, it's a moderately strong starting hand in No Limit Texas Hold'em. The hand has decent value against some pocket pairs and suited connectors, but is somewhat underpowered against sets like A-A. The pot size is 49.0 chips, and the fact that the previous raises have all doubled and quadrupled suggests that the board likely has some reasonable potential, or at least players remaining are willing to bet with their current holdings.
#
# Positionally, you are the button (BB), which is the passive position but you can still act on this board if you have missed a flop. Since UTG and HJ both folded, it may be worthwhile to consider a call or even a possible raise here, rather than be forced to wait for the turn and potentially have to pay off some larger bet.
#
# Given the action before you, you might consider folding to the BB raise, as it could be a sign that the majority of the remaining
# Extracted:
# <reasoning>
# Given your holding of A♠5♠, it's a moderately strong starting hand in No Limit Texas Hold'em. The hand has decent value against some pocket pairs and suited connectors, but is somewhat underpowered against sets like A-A. The pot size is 49.0 chips, and the fact that the previous raises have all doubled and quadrupled suggests that the board likely has some reasonable potential, or at least players remaining are willing to bet with their current holdings.
#
# Positionally, you are the button (BB), which is the passive position but you can still act on this board if you have missed a flop. Since UTG and HJ both folded, it may be worthwhile to consider a call or even a possible raise here, rather than be forced to wait for the turn and potentially have to pay off some larger bet.
#
# Given the action before you, you might consider folding to the BB raise, as it could be a sign that the majority of the remaining
# -------------------- Question:
#
#
# You are a specialist in playing 6-handed No Limit Texas Holdem. The following will be a game scenario and you need to make the optimal decision.
#
# Here is a game summary:
#
# The small blind is 0.5 chips and the big blind is 1 chips. Everyone started with 100 chips.
# The player positions involved in this game are UTG, HJ, CO, BTN, SB, BB.
# In this hand, your position is BB, and your holding is [Ace of Heart and Six of Heart].
# Before the flop, SB raise 3.0 chips, and BB call. Assume that all other players that is not mentioned folded.
# The flop comes Queen Of Club, Eight Of Club, and Ace Of Club, then SB check, and BB check.
# The turn comes Three Of Club, then SB bet 8 chips, BB raise 23 chips, and SB call.
# The river comes Queen Of Heart, then SB check.
#
#
# Now it is your turn to make a move.
# To remind you, the current pot size is 52.0 chips, and your holding is [Ace of Heart and Six of Heart].
#
# Decide on an action based on the strength of your hand on this board, your position, and actions before you. Do not explain your answer.
# Your optimal action is:
# Answer:
# raise 74
# Response:
# <reasoning>
# Given the information, let's analyze the situation:
#
# - SB has bet 8 chips on the turn, indicating he believes he has a strong hand.
# - BB then raised SB's bet from 8 chips to 31 chips, showing he thinks he can beat SB's bet.
# - SB called, implying that SB has a strong hand as well or SB has value bet believing that BB won't call his raise.
#
# Your holding is [Ace of Heart and Six of Heart]. Facing the turn board of [Queen of Club, Eight of Club, Ace of Club, Three of Club], it's hard to make a play that could win against SB's strong hand.
# In such a situation, you want to maximize your profit or minimize your loss. If you check, SB and BB may both bluff check. If you bet 31 chips (to match BB's raise), you create an opportunity for SB to either call or fold. Failing to hit one of the
# Extracted:
# <reasoning>
# Given the information, let's analyze the situation:
#
# - SB has bet 8 chips on the turn, indicating he believes he has a strong hand.
# - BB then raised SB's bet from 8 chips to 31 chips, showing he thinks he can beat SB's bet.
# - SB called, implying that SB has a strong hand as well or SB has value bet believing that BB won't call his raise.
#
# Your holding is [Ace of Heart and Six of Heart]. Facing the turn board of [Queen of Club, Eight of Club, Ace of Club, Three of Club], it's hard to make a play that could win against SB's strong hand.
# In such a situation, you want to maximize your profit or minimize your loss. If you check, SB and BB may both bluff check. If you bet 31 chips (to match BB's raise), you create an opportunity for SB to either call or fold. Failing to hit one of the
# -------------------- Question:
#
#
# You are a specialist in playing 6-handed No Limit Texas Holdem. The following will be a game scenario and you need to make the optimal decision.
#
# Here is a game summary:
#
# The small blind is 0.5 chips and the big blind is 1 chips. Everyone started with 100 chips.
# The player positions involved in this game are UTG, HJ, CO, BTN, SB, BB.
# In this hand, your position is UTG, and your holding is [Queen of Spade and Queen of Club].
# Before the flop, UTG raise 2.0 chips, and BB call. Assume that all other players that is not mentioned folded.
# The flop comes Ace Of Club, King Of Spade, and Seven Of Diamond, then BB check, and UTG check.
# The turn comes King Of Diamond, then BB check, UTG bet 3 chips, and BB call.
# The river comes Ace Of Heart, then BB check.
#
#
# Now it is your turn to make a move.
# To remind you, the current pot size is 10.0 chips, and your holding is [Queen of Spade and Queen of Club].
#
# Decide on an action based on the strength of your hand on this board, your position, and actions before you. Do not explain your answer.
# Your optimal action is:
# Answer:
# check
# Response:
# <reasoning>
# Based on the board (Ac Ks 7d Kd Kh Ah), you have a pair of queens (Queen of Spade and Queen of Club), which is a strong starting hand. Here are the considerations:
# - Position: You are the UTG, which means you are often able to see the flop, and your hand is strong enough to justify a raised bet when it's checked to you on the turn.
# - Pot size: The current pot size is $10, and with three players remaining (you, BB, and the player who folded), you are probably the most likely to win the pot.
# - Bet size: Your opponent (BB) has called your bet of 3 chips on the turn with only folded players aside. This suggests he probably thinks you have a strong hand as well, or he has a hand that he feels can compete with yours.
# - Action before: UTG raised, then BB called, which is a solid move showing pref
# Extracted:
# <reasoning>
# Based on the board (Ac Ks 7d Kd Kh Ah), you have a pair of queens (Queen of Spade and Queen of Club), which is a strong starting hand. Here are the considerations:
# - Position: You are the UTG, which means you are often able to see the flop, and your hand is strong enough to justify a raised bet when it's checked to you on the turn.
# - Pot size: The current pot size is $10, and with three players remaining (you, BB, and the player who folded), you are probably the most likely to win the pot.
# - Bet size: Your opponent (BB) has called your bet of 3 chips on the turn with only folded players aside. This suggests he probably thinks you have a strong hand as well, or he has a hand that he feels can compete with yours.
# - Action before: UTG raised, then BB called, which is a solid move showing pref
# -------------------- Question:
#
#
# You are a specialist in playing 6-handed No Limit Texas Holdem. The following will be a game scenario and you need to make the optimal decision.
#
# Here is a game summary:
#
# The small blind is 0.5 chips and the big blind is 1 chips. Everyone started with 100 chips.
# The player positions involved in this game are UTG, HJ, CO, BTN, SB, BB.
# In this hand, your position is BB, and your holding is [Jack of Club and Five of Club].
# Before the flop, UTG raise 2.0 chips, and BB call. Assume that all other players that is not mentioned folded.
# The flop comes Jack Of Heart, Four Of Heart, and Five Of Spade, then BB check, UTG bet 3 chips, BB raise 10 chips, and UTG call.
# The turn comes King Of Heart, then BB check, and UTG bet 18 chips.
#
#
# Now it is your turn to make a move.
# To remind you, the current pot size is 42.0 chips, and your holding is [Jack of Club and Five of Club].
#
# Decide on an action based on the strength of your hand on this board, your position, and actions before you. Do not explain your answer.
# Your optimal action is:
# Answer:
# fold
# Response:
# <reasoning>
# Given the current board: Jack of Heart, Four of Heart, Five of Spade, King of Heart, the board is now [J,H], [4,H], [5,S], [Q,H]. This is a relatively strong board for value or semi-bluffing. UTG has bet 3 chips on the turn, and BB raised and called a lot, indicating that he has a strong hand.
#
# You have Jack of Club and Five of Club as your holding. Since you are at the button, you are in the middle of the action and can choose between calling and potentially bluffing. If you call, you will need to consider UTG's range and his decision to raise strongly on the turn. On the other hand, if you play the weak hand and only call UTG’s weaker check or raise, you might miss a great position to bluff UTG the river.
# </reasoning>
#
# <answer>
# Call
# </answer>
# Extracted:
# Call
# -------------------- Question:
#
#
# You are a specialist in playing 6-handed No Limit Texas Holdem. The following will be a game scenario and you need to make the optimal decision.
#
# Here is a game summary:
#
# The small blind is 0.5 chips and the big blind is 1 chips. Everyone started with 100 chips.
# The player positions involved in this game are UTG, HJ, CO, BTN, SB, BB.
# In this hand, your position is BB, and your holding is [Seven of Diamond and Seven of Club].
# Before the flop, BTN raise 2.5 chips, and BB call. Assume that all other players that is not mentioned folded.
# The flop comes Jack Of Heart, Four Of Heart, and Five Of Spade, then BB check, BTN bet 4 chips, and BB call.
# The turn comes Two Of Diamond, then BB check, BTN bet 16 chips, and BB call.
# The river comes Queen Of Club, then BB check, and BTN bet 34 chips.
#
#
# Now it is your turn to make a move.
# To remind you, the current pot size is 75.0 chips, and your holding is [Seven of Diamond and Seven of Club].
#
# Decide on an action based on the strength of your hand on this board, your position, and actions before you. Do not explain your answer.
# Your optimal action is:
# Answer:
# fold
# Response:
# <reasoning>
# Given the situation, the player in position to act (BB) needs to consider their position, the strength of their own hand, and the actions made so far by the players in front of them. Currently, BB has raised and been called by BTN, and the bet size on the turn was 16 chips by BTN, implying that BTN thinks this hand has potential value. With the pot at 75 chips and the BB (current player) out of position, betting or raising potentially becomes advantageous.
#
# BB now has two main options:
# 1. Fold - Given the raised pre-flop and the call by BTN, it seems that BTN is willing to risk chips in position, which might give BB the opportunity to check and let the pressure of the action be saved for the next player or even fold automatically if the board doesn老鼠棋 continues to improve.
# 2. Check and decide on the final bet size - This option allows BB to see the river without having to make
# Extracted:
# <reasoning>
# Given the situation, the player in position to act (BB) needs to consider their position, the strength of their own hand, and the actions made so far by the players in front of them. Currently, BB has raised and been called by BTN, and the bet size on the turn was 16 chips by BTN, implying that BTN thinks this hand has potential value. With the pot at 75 chips and the BB (current player) out of position, betting or raising potentially becomes advantageous.
#
# BB now has two main options:
# 1. Fold - Given the raised pre-flop and the call by BTN, it seems that BTN is willing to risk chips in position, which might give BB the opportunity to check and let the pressure of the action be saved for the next player or even fold automatically if the board doesn老鼠棋 continues to improve.
# 2. Check and decide on the final bet size - This option allows BB to see the river without having to make

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Now let's try the model we just trained! First, let's first try the model without any GRPO trained:

# %%
text = tokenizer.apply_chat_template([
    {"role" : "user", "content" : "How many r's are in strrawberry?"},
], tokenize = False, add_generation_prompt = True)

from vllm import SamplingParams
sampling_params = SamplingParams(
    temperature = 0.8,
    top_p = 0.95,
    max_tokens = 1024,
)
output = model.fast_generate(
    [text],
    sampling_params = sampling_params,
    lora_request = None,
)[0].outputs[0].text

output
# Out:
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.30it/s, est. speed input: 50.92 toks/s, output: 20.89 toks/s]
# 'There are no letters "r" in the word "strawberry."'

# %% [markdown]
# And now with the LoRA we just trained with GRPO - we first save the LoRA first!

# %%
model.save_lora("grpo_saved_lora")

# %% [markdown]
# Now we load the LoRA and test:

# %%
text = tokenizer.apply_chat_template([
    {"role" : "system", "content" : SYSTEM_PROMPT},
    {"role" : "user", "content" : "How many letter e's are there in word needed?"},
], tokenize = False, add_generation_prompt = True)

from vllm import SamplingParams
sampling_params = SamplingParams(
    temperature = 0.8,
    top_p = 0.95,
    max_tokens = 1024,
)
output = model.fast_generate(
    text,
    sampling_params = sampling_params,
    lora_request = model.load_lora("grpo_saved_lora"),
)[0].outputs[0].text

output
# Out:
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.46s/it, est. speed input: 10.33 toks/s, output: 31.66 toks/s]
# 'I need the word "needed" to count the occurrences of the letter \'e\'. Let\'s analyze it:\n\n1. The word "needed" consists of 7 letters.\n2. The letter \'e\' appears twice in this word: once in the third position and once in the sixth position.\n\nTherefore, the answer is:\n\n<answer>2</answer>\n\n<reasoning>\nTo be thorough, I\'ve counted each occurrence of \'e\' within the word:\n- n-e-d-d\n- The second \'e\' is in the third position\n- The first \'e\' is in the sixth position\n- There are no other \'e\'s in "needed"\n</reasoning>'

# %% [markdown]
# Our reasoning model is much better - it's not always correct, since we only trained it for an hour or so - it'll be better if we extend the sequence length and train for longer!

# %% [markdown]
# <a name="Save"></a>
# ### Saving to float16 for VLLM
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16 or `merged_4bit` for int4. We also allow `lora` adapters as a fallback. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
# Merge to 16bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_16bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_16bit", token = "")

# Merge to 4bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_4bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_4bit", token = "")

# Just LoRA adapters
if False: model.save_pretrained_merged("model", tokenizer, save_method = "lora",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "lora", token = "")

# %% [markdown]
# ### GGUF / llama.cpp Conversion
# To save to `GGUF` / `llama.cpp`, we support it natively now! We clone `llama.cpp` and we default save it to `q8_0`. We allow all methods like `q4_k_m`. Use `save_pretrained_gguf` for local saving and `push_to_hub_gguf` for uploading to HF.
#
# Some supported quant methods (full list on our [Wiki page](https://github.com/unslothai/unsloth/wiki#gguf-quantization-options)):
# * `q8_0` - Fast conversion. High resource use, but generally acceptable.
# * `q4_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q4_K.
# * `q5_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q5_K.
#
# [**NEW**] To finetune and auto export to Ollama, try our [Ollama notebook](https://colab.research.google.com/drive/1WZDi7APtQ9VsvOrQSSC5DDtxq159j8iZ?usp=sharing)

# %%
# Save to 8bit Q8_0
if False: model.save_pretrained_gguf("model", tokenizer,)
# Remember to go to https://huggingface.co/settings/tokens for a token!
# And change hf to your username!
if False: model.push_to_hub_gguf("hf/model", tokenizer, token = "")

# Save to 16bit GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "f16")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "f16", token = "")

# Save to q4_k_m GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "q4_k_m")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "q4_k_m", token = "")

# Save to multiple GGUF options - much faster if you want multiple!
if False:
    model.push_to_hub_gguf(
        "hf/model", # Change hf to your username!
        tokenizer,
        quantization_method = ["q4_k_m", "q8_0", "q5_k_m",],
        token = "",
    )

# %% [markdown]
# Now, use the `model-unsloth.gguf` file or `model-unsloth-Q4_K_M.gguf` file in llama.cpp or a UI based system like Jan or Open WebUI. You can install Jan [here](https://github.com/janhq/jan) and Open WebUI [here](https://github.com/open-webui/open-webui)
#
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Llama 3.2 Conversational notebook. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(1B_and_3B)-Conversational.ipynb)
# 2. Saving finetunes to Ollama. [Free notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)
# 3. Llama 3.2 Vision finetuning - Radiography use case. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(11B)-Vision.ipynb)
# 6. See notebooks for DPO, ORPO, Continued pretraining, conversational finetuning and more on our [documentation](https://docs.unsloth.ai/get-started/unsloth-notebooks)!
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
# </div>
